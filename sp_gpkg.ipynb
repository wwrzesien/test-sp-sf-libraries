# %% [markdown]
# # Library: sp
# Data: airport database. Source: .gpkg

# %%
# Import libraries
library(sp)
library(rgdal)
library(rgeos)
# Out:
# rgdal: version: 1.5-16, (SVN revision 1050)
# Geospatial Data Abstraction Library extensions to R successfully loaded
# Loaded GDAL runtime: GDAL 3.1.4, released 2020/10/20
# Path to GDAL shared files: /home/wojtek/anaconda3/envs/r_env/share/gdal
# GDAL binary built with GEOS: TRUE
# Loaded PROJ runtime: Rel. 7.1.1, September 1st, 2020, [PJ_VERSION: 711]
# Path to PROJ shared files: /home/wojtek/anaconda3/envs/r_env/share/proj
# PROJ CDN enabled: TRUE
# Linking to sp version:1.4-2
# To mute warnings of possible GDAL/OSR exportToProj4() degradation,
# use options("rgdal_show_exportToProj4_warnings"="none") before loading rgdal.
# rgeos version: 0.5-5, (SVN revision 640)
#  GEOS runtime version: 3.8.1-CAPI-1.13.3
#  Linking to sp version: 1.4-2
#  Polygon checking: TRUE

# %%
# Open file 
# data_path_zip <- "./data/oproad_gpkg_gb.zip"
# unzip(zipfile=data_path_zip, files="data/oproad_gb.gpkg")

# data_path_gpkg <- "./data/oproad_gb.gpkg"
# raw_data_gpkg <- readOGR(dsn=data_path_gpkg)

data_path_zip <- "./data/data_gpkg.zip"
unzip(zipfile=data_path_zip, files="nz-roads-road-section-geometry.gpkg", exdir="./data")

data_path_gpkg <- "./data/nz-roads-road-section-geometry.gpkg"
raw_data_gpkg <- readOGR(dsn=data_path_gpkg)
# Out:
# Warning message in OGRSpatialRef(dsn, layer, morphFromESRI = morphFromESRI, dumpSRS = dumpSRS, :
# “Discarded datum New_Zealand_Geodetic_Datum_2000 in CRS definition: +proj=longlat +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +no_defs”
# OGR data source with driver: GPKG
# Source: "/home/wojtek/Documents/Studia/Sem_II/SPDB/testSpSfLibraries/data/nz-roads-road-section-geometry.gpkg", layer: "nz_roads_road_section_geometry"
# with 346418 features
# It has 15 fields

# %%
plot(raw_data_gpkg)
# Out:
# plot without title

# %%
head(raw_data_gpkg)
# Out:
#                                    geometry road_section_geometry_id
# 1 MULTILINESTRING((174.5955 -36.08074 ...))                  1324415
# 2 MULTILINESTRING((174.5929 -36.08011 ...))                  1324419
# 3 MULTILINESTRING((175.0301 -37.24905 ...))                  1324445
# 4 MULTILINESTRING((175.0301 -37.24905 ...))                  1324446
# 5 MULTILINESTRING((176.2475 -37.68784 ...))                  1324448
# 6 MULTILINESTRING((176.2464 -37.69079 ...))                  1324451
#    geometry_class road_type road_section_id geometry_provider geometry_manager
# 1 Addressing Road   Unknown          385550              LINZ             LINZ
# 2 Addressing Road   Unknown          385554              LINZ             LINZ
# 3 Addressing Road   Unknown          385578              LINZ             LINZ
# 4 Addressing Road   Unknown          385579              LINZ             LINZ
# 5 Addressing Road   Unknown          385581              LINZ             LINZ
# ...
